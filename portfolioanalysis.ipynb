# %%
# !pip install numpy pandas matplotlib
print("libraries installed")
# Out:
# ...
# libraries installed

# %%
import os
os.chdir('/content')
print(os.listdir('/content'))
# Out:
# ['.config', 'portfolio_returns.csv', 'portfolio_analytics.py', 'requirements.txt', 'README.md', 'sample_data']

# %%
exec(open('portfolio_analytics.py').read())
# Out:
# Loading portfolio data...
# Computing performance metrics...
#
# ...
#      PORTFOLIO PERFORMANCE ANALYTICS REPORT
# ...
#   Total Return (Portfolio)           : 76.20%
#   Total Return (Benchmark)           : 16.73%
#   Annual Return (Portfolio)          : 20.78%
#   Annual Return (Benchmark)          : 5.29%
#   Annualised Volatility              : 19.72%
#   Benchmark Volatility               : 17.79%
#   Sharpe Ratio                       : 0.727
#   Sortino Ratio                      : 1.274
#   Calmar Ratio                       : 0.983
#   Maximum Drawdown                   : -21.15%
#   Beta                               : 1.051
#   Alpha (Annual)                     : 15.55%
#   Information Ratio                  : 2.230
#   Tracking Error                     : 6.32%
#   Win Rate (Daily)                   : 51.5%
#
# ── Top Drawdown Periods ──────────────────────────────
#      Start        End Max Drawdown  Duration (Days)
# 2021-01-21 2021-07-19      -14.31%              179
# ...

# %%
# VIEW DASHBOARD
from IPython.display import Image
Image('/content/portfolio_dashboard.png')

# %%
# PERFORMANCE METRIC
import pandas as pd
df = pd.read_csv('/content/performance_metrics.csv')
print(df.T)
# Out:
#                                  0
# Total Return (Portfolio)    76.20%
# Total Return (Benchmark)    16.73%
# Annual Return (Portfolio)   20.78%
# Annual Return (Benchmark)    5.29%
# Annualised Volatility       19.72%
# Benchmark Volatility        17.79%
# Sharpe Ratio                 0.727
# Sortino Ratio                1.274
# Calmar Ratio                 0.983
# Maximum Drawdown           -21.15%
# Beta                         1.051
# Alpha (Annual)              15.55%
# Information Ratio             2.23
# Tracking Error               6.32%
# Win Rate (Daily)             51.5%

# %%
# view result
df2 = pd.read_csv('/content/attribution_results.csv')
print(df2)
# Out:
#        Sector Port Weight Bench Weight Active Weight Allocation Effect  \
# 0          IT       28.0%        22.0%         +6.0%           -0.971%
# 1  Financials       30.0%        32.0%         -2.0%           -0.206%
# 2      Energy       15.0%        18.0%         -3.0%           -0.219%
# 3        FMCG       15.0%        16.0%         -1.0%           +0.381%
# 4  Healthcare       12.0%        12.0%         +0.0%           -0.000%
#
#   Selection Effect Total Effect
# 0          -0.056%      -1.027%
# 1          -0.261%      -0.468%
# 2          +0.034%      -0.186%
# 3          -0.125%      +0.256%
# 4          -0.000%      -0.000%
